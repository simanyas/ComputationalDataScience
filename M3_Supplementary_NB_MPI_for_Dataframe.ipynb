# %% [markdown]
# # Advanced Certification Program in Computational Data Science
# ## A program by IISc and TalentSprint
# ### Supplementary Notebook: Implementation of send and receive operation on a dataset using MPI

# %% [markdown]
# ## Learning Objectives

# %% [markdown]
# At the end of the mini-project, you will be able to :
#
# * implement the collective communication operations like scatter, gather, broadcast on a dataset using MPI

# %% [markdown]
# ### Dataset

# %% [markdown]
# Here, we will be using the “Iris dataset”.The Iris dataset contains 50 samples of 3 different species of iris (150 samples total).
#
# The columns in this dataset are:
#
# - SepalLength (cm)
# - SepalWidth (cm)
# - PetalLength (cm)
# - PetalWidth (cm)
# - Species

# %% [markdown]
# **Note:** We will be using the mpi4py Python package for MPI based code implementation

# %% [markdown]
# **Run the below code to install mpi4py package**

# %%
# !pip install mpi4py
# Out:
# Collecting mpi4py
#   Downloading mpi4py-3.1.3.tar.gz (2.5 MB)
#      |████████████████████████████████| 2.5 MB 31.1 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Building wheels for collected packages: mpi4py
#   Building wheel for mpi4py (PEP 517) ... done
#   Created wheel for mpi4py: filename=mpi4py-3.1.3-cp37-cp37m-linux_x86_64.whl size=2185314 sha256=ac1ffc9ceb680907ef4a5c725cf1bd62d8033a69f134cb4e8265b0fed3b562d6
#   Stored in directory: /root/.cache/pip/wheels/7a/07/14/6a0c63fa2c6e473c6edc40985b7d89f05c61ff25ee7f0ad9ac
# Successfully built mpi4py
# Installing collected packages: mpi4py
# Successfully installed mpi4py-3.1.3

# %% [markdown]
# #### Importing Necessary Packages

# %%
# Importing pandas
import pandas as pd 
# Importing Numpy
import numpy as np 
# Importing MPI from mpi4py package
from mpi4py import MPI 
# Importing sqrt function from the Math
from math import sqrt 
# Importing Decimal, ROUND_HALF_UP functions from the decimal package
from decimal import Decimal, ROUND_HALF_UP
import time 
from sklearn import datasets

# %%
#@title Downloading the data
iris = datasets.load_iris()
dataset = pd.DataFrame(iris.data, columns = iris.feature_names)
dataset['species'] = iris.target
dataset['species'] = dataset['species'].apply(lambda x: iris.target_names[x])
dataset.to_csv('iris_dataset.csv', index=False)
print("Dataset downloaded successfully!")

# %% [markdown]
# ### Load data
#
# Write a function that takes the filename as input and loads the data in a pandas dataframe.

# %%
FILENAME = "/content/iris_dataset.csv" # Storing File path
# Defining a function to load the data
def loadData(filename): 
    # Loading the dataset with column names as 
    data = pd.read_csv(filename)
    # Returning the dataframe
    return data
# Calling the function loadData and storing the dataframe in a variable named df
df = loadData(FILENAME)
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#   species
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %% [markdown]
# ### Point-to-point Blocking Communication

# %% [markdown]
# **Passing the entire Dataframe**

# %%
# %%writefile passing_dataframe.py
from mpi4py import MPI # Importing mpi4py package from MPI module
import pandas as pd
import numpy as np
# Defining a function

FILENAME = "/content/iris_dataset.csv" # Storing File path
# Defining a function to load the data
def loadData(filename): 
    # Loading the dataset with column names as 
    data = pd.read_csv(filename)
    # Returning the dataframe
    return data
# Calling the function loadData and storing the dataframe in a variable named df
df = loadData(FILENAME)

def main():
    # Creating a communicator
    comm = MPI.COMM_WORLD
    # number of the process running the code
    rank = comm.Get_rank()
    # total number of processes running
    size = comm.Get_size()
    # master process
    if rank == 0:
        # Generate a dictionary with arbitrary data in it
        data = df
        # master process sends data to worker processes by
        # going through the ranks of all worker processes
        for i in range(1, size):
            # Sending data
            comm.send(data, dest=i, tag=i)
            # Displaying the results
            print('Process {} sent data:'.format(rank), data)
    # worker processes
    else:
        # each worker process receives data from master process
        data = comm.recv(source=0, tag=rank)
        # Displaying the results
        print('Process {} received data:'.format(rank), data)
# Calling the function
main()
# Out:
# Writing passing_df.py

# %%
# !mpirun --allow-run-as-root -np 4 python passing_dataframe.py
# Out:
# Process 1 received data:      sepal length (cm)  ...    species
# 0                  5.1  ...     setosa
# 1                  4.9  ...     setosa
# 2                  4.7  ...     setosa
# 3                  4.6  ...     setosa
# 4                  5.0  ...     setosa
# ..                 ...  ...        ...
# 145                6.7  ...  virginica
# 146                6.3  ...  virginica
# 147                6.5  ...  virginica
# 148                6.2  ...  virginica
# 149                5.9  ...  virginica
#
# [150 rows x 5 columns]
# Process 0 sent data:      sepal length (cm)  ...    species
# 0                  5.1  ...     setosa
# 1                  4.9  ...     setosa
# 2                  4.7  ...     setosa
# 3                  4.6  ...     setosa
# 4                  5.0  ...     setosa
# ..                 ...  ...        ...
# 145                6.7  ...  virginica
# 146                6.3  ...  virginica
# 147                6.5  ...  virginica
# 148                6.2  ...  virginica
# 149                5.9  ...  virginica
#
# [150 rows x 5 columns]
# Process 0 sent data:      sepal length (cm)  ...    species
# 0                  5.1  ...     setosa
# 1                  4.9  ...     setosa
# 2                  4.7  ...     setosa
# 3                  4.6  ...     setosa
# 4                  5.0  ...     setosa
# ..                 ...  ...        ...
# 145                6.7  ...  virginica
# 146                6.3  ...  virginica
# 147                6.5  ...  virginica
# 148                6.2  ...  virginica
# 149                5.9  ...  virginica
#
# [150 rows x 5 columns]Process 2 received data:      sepal length (cm)  ...    species
# 0                  5.1  ...     setosa
# 1                  4.9  ...     setosa
# 2                  4.7  ...     setosa
# 3                  4.6  ...     setosa
# 4                  5.0  ...     setosa
# ..                 ...  ...        ...
# 145                6.7  ...  virginica
# 146                6.3  ...  virginica
# 147                6.5  ...  virginica
# 148                6.2  ...  virginica
# 149                5.9  ...  virginica
#
# [150 rows x 5 columns]
#
# Process 0 sent data:      sepal length (cm)  ...    species
# 0                  5.1  ...     setosa
# 1                  4.9  ...     setosa
# 2                  4.7  ...     setosa
# 3                  4.6  ...     setosa
# 4                  5.0  ...     setosa
# ..                 ...  ...        ...
# 145                6.7  ...  virginica
# 146                6.3  ...  virginica
# 147                6.5  ...  virginica
# 148                6.2  ...  virginica
# 149                5.9  ...  virginica
#
# [150 rows x 5 columns]
# Process 3 received data:      sepal length (cm)  ...    species
# 0                  5.1  ...     setosa
# 1                  4.9  ...     setosa
# 2                  4.7  ...     setosa
# 3                  4.6  ...     setosa
# 4                  5.0  ...     setosa
# ..                 ...  ...        ...
# 145                6.7  ...  virginica
# 146                6.3  ...  virginica
# 147                6.5  ...  virginica
# 148                6.2  ...  virginica
# 149                5.9  ...  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ### Collective Communication
#
# In MPI for Python, the `Comm.Bcast`, `Comm.Scatter`, `Comm.Gather`, `Comm.Allgather`, `Comm.Alltoall` methods provide support for collective communications of memory buffers. The lower-case variants `Comm.bcast`, `Comm.scatter`, `Comm.gather`, `Comm.allgather` and `Comm.alltoall` can communicate general Python objects.

# %% [markdown]
# #### **Broadcasting the entire Dataframe**

# %%
# %%writefile BroadcastingDataframe.py 
from mpi4py import MPI # Importing mpi4py package from MPI module
import numpy as np
import pandas as pd

FILENAME = "/content/iris_dataset.csv" # Storing File path
# Defining a function to load the data
def loadData(filename): 
    # Loading the dataset with column names as 
    data = pd.read_csv(filename)
    # Returning the dataframe
    return data
# Calling the function loadData and storing the dataframe in a variable named df
df = loadData(FILENAME)

# Defining a function 
def main():
    comm = MPI.COMM_WORLD
    id = comm.Get_rank()            #number of the process running the code
    numProcesses = comm.Get_size()  #total number of processes running
    if id == 0:
        # Generate a dictionary with arbitrary data in it
        data = df
    else:
        # start with empty data
        data = None
    # Broadcasting the data
    data = comm.bcast(data, root=0)
    # Printing the data along with the id number
    print('Rank: ', id,', received data: ' , data, '\n')
    
# Calling a function
main()
# Out:
# Writing BroadcastingDataframe.py

# %%
! mpirun --allow-run-as-root -np 4 python BroadcastingDataframe.py
# Out:
# Rank:  0 , received data:       sepal length (cm)  ...    species
# 0                  5.1  ...     setosa
# 1                  4.9  ...     setosa
# 2                  4.7  ...     setosa
# 3                  4.6  ...     setosa
# 4                  5.0  ...     setosa
# ..                 ...  ...        ...
# 145                6.7  ...  virginica
# 146                6.3  ...  virginica
# 147                6.5  ...  virginica
# 148                6.2  ...  virginica
# 149                5.9  ...  virginica
#
# [150 rows x 5 columns]
#
# Rank:  2 , received data:       sepal length (cm)  ...    species
# 0                  5.1  ...     setosa
# 1                  4.9  ...     setosa
# 2                  4.7  ...     setosa
# 3                  4.6  ...     setosa
# 4                  5.0  ...     setosa
# ..                 ...  ...        ...
# 145                6.7  ...  virginica
# 146                6.3  ...  virginica
# 147                6.5  ...  virginica
# 148                6.2  ...  virginica
# 149                5.9  ...  virginica
#
# [150 rows x 5 columns]Rank:  3 , received data:       sepal length (cm)  ...    species
# 0                  5.1  ...     setosa
# 1                  4.9  ...     setosa
# 2                  4.7  ...     setosa
# 3                  4.6  ...     setosa
# 4                  5.0  ...     setosa
# ..                 ...  ...        ...
# 145                6.7  ...  virginica
# 146                6.3  ...  virginica
# 147                6.5  ...  virginica
# 148                6.2  ...  virginica
# 149                5.9  ...  virginica
#
# [150 rows x 5 columns]
#
# Rank:  1 , received data:       sepal length (cm)  ...    species
# 0                  5.1  ...     setosa
# 1                  4.9  ...     setosa
# 2                  4.7  ...     setosa
# 3                  4.6  ...     setosa
# 4                  5.0  ...     setosa
# ..                 ...  ...        ...
# 145                6.7  ...  virginica
# 146                6.3  ...  virginica
# 147                6.5  ...  virginica
# 148                6.2  ...  virginica
# 149                5.9  ...  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# #### **Scatter Operation on the Dataframe**
#
# - Create a function to divide the dataframe equally among different processes.
# - Perform scatter operation

# %%
# %%writefile ScatteringDataframe.py
from mpi4py import MPI # Importing mpi4py package from MPI module
import numpy as np
import pandas as pd
from decimal import Decimal, ROUND_HALF_UP # Importing Decimal, ROUND_HALF_UP functions from the decimal package

FILENAME = "/content/iris_dataset.csv" # Storing File path
# Defining a function to load the data
def loadData(filename): 
    # Loading the dataset with column names as 
    data = pd.read_csv(filename)
    # Returning the dataframe
    return data
# Calling the function loadData and storing the dataframe in a variable named df
df = loadData(FILENAME)

def dividing_data(dataset, size_of_workers):
    #Divide the data among the workers
    slice_for_each_worker = int(Decimal(dataset.shape[0]/size_of_workers).quantize(Decimal('1.'), rounding = ROUND_HALF_UP))      
    print('Slice of data for each worker: {}'.format(slice_for_each_worker))
    data_for_worker = []
    for i in range(0, size_of_workers):
        if i < size_of_workers - 1:
            data_for_worker.append(dataset[slice_for_each_worker*i:slice_for_each_worker*(i+1)])
        else:
            data_for_worker.append(dataset[slice_for_each_worker*i:])
    return data_for_worker

# Defining a function 
def main():
    # communicator
    comm = MPI.COMM_WORLD
    rank = comm.Get_rank()   # number of the process running the code
    size = comm.Get_size()   # total number of processes running
    data = None # Starting with an empty  data
    if rank == 0: 
        # Creating a Numpy array.
        data = dividing_data(df, size)
    # scatter operation
    received_data = comm.scatter(data, root=0)
    # Displaying the result
    print('Rank: ', rank, ', recvbuf: ', received_data)

# Calling the main function
main()
# Out:
# Writing ScatteringDataframe.py

# %%
! mpirun --allow-run-as-root -np 4 python ScatteringDataframe.py
# Out:
# Slice of data for each worker: 38
# Rank:  2 , recvbuf:       sepal length (cm)  ...     species
# 76                 6.8  ...  versicolor
# 77                 6.7  ...  versicolor
# 78                 6.0  ...  versicolor
# 79                 5.7  ...  versicolor
# 80                 5.5  ...  versicolor
# 81                 5.5  ...  versicolor
# 82                 5.8  ...  versicolor
# 83                 6.0  ...  versicolor
# 84                 5.4  ...  versicolor
# 85                 6.0  ...  versicolor
# 86                 6.7  ...  versicolor
# 87                 6.3  ...  versicolor
# 88                 5.6  ...  versicolor
# 89                 5.5  ...  versicolor
# 90                 5.5  ...  versicolor
# 91                 6.1  ...  versicolor
# 92                 5.8  ...  versicolor
# 93                 5.0  ...  versicolor
# 94                 5.6  ...  versicolor
# 95                 5.7  ...  versicolor
# 96                 5.7  ...  versicolor
# 97                 6.2  ...  versicolor
# 98                 5.1  ...  versicolor
# 99                 5.7  ...  versicolor
# 100                6.3  ...   virginica
# 101                5.8  ...   virginica
# 102                7.1  ...   virginica
# 103                6.3  ...   virginica
# 104                6.5  ...   virginica
# 105                7.6  ...   virginica
# 106                4.9  ...   virginica
# 107                7.3  ...   virginica
# 108                6.7  ...   virginica
# 109                7.2  ...   virginica
# 110                6.5  ...   virginica
# 111                6.4  ...   virginica
# 112                6.8  ...   virginica
# 113                5.7  ...   virginica
#
# [38 rows x 5 columns]Rank:  0 , recvbuf:      sepal length (cm)  ...  species
# 0                 5.1  ...   setosa
# 1                 4.9  ...   setosa
# 2                 4.7  ...   setosa
# 3                 4.6  ...   setosa
# 4                 5.0  ...   setosa
# 5                 5.4  ...   setosa
# 6                 4.6  ...   setosa
# 7                 5.0  ...   setosa
# 8                 4.4  ...   setosa
# 9                 4.9  ...   setosa
# 10                5.4  ...   setosa
# 11                4.8  ...   setosa
# 12                4.8  ...   setosa
# 13                4.3  ...   setosa
# 14                5.8  ...   setosa
# 15                5.7  ...   setosa
# 16                5.4  ...   setosa
# 17                5.1  ...   setosa
# 18                5.7  ...   setosa
# 19                5.1  ...   setosa
# 20                5.4  ...   setosa
# 21                5.1  ...   setosa
# 22                4.6  ...   setosa
# 23                5.1  ...   setosa
# 24                4.8  ...   setosa
# 25                5.0  ...   setosa
# 26                5.0  ...   setosa
# 27                5.2  ...   setosa
# 28                5.2  ...   setosa
# 29                4.7  ...   setosa
# 30                4.8  ...   setosa
# 31                5.4  ...   setosa
# 32                5.2  ...   setosa
# 33                5.5  ...   setosa
# 34                4.9  ...   setosa
# 35                5.0  ...   setosa
# 36                5.5  ...   setosa
# 37                4.9  ...   setosa
#
# [38 rows x 5 columns]
#
# Rank:  3 , recvbuf:       sepal length (cm)  ...    species
# 114                5.8  ...  virginica
# 115                6.4  ...  virginica
# 116                6.5  ...  virginica
# 117                7.7  ...  virginica
# 118                7.7  ...  virginica
# 119                6.0  ...  virginica
# 120                6.9  ...  virginica
# 121                5.6  ...  virginica
# 122                7.7  ...  virginica
# 123                6.3  ...  virginica
# 124                6.7  ...  virginica
# 125                7.2  ...  virginica
# 126                6.2  ...  virginica
# 127                6.1  ...  virginica
# 128                6.4  ...  virginica
# 129                7.2  ...  virginica
# 130                7.4  ...  virginica
# 131                7.9  ...  virginica
# 132                6.4  ...  virginica
# 133                6.3  ...  virginica
# 134                6.1  ...  virginica
# 135                7.7  ...  virginica
# 136                6.3  ...  virginica
# 137                6.4  ...  virginica
# 138                6.0  ...  virginica
# 139                6.9  ...  virginica
# 140                6.7  ...  virginica
# 141                6.9  ...  virginica
# 142                5.8  ...  virginica
# 143                6.8  ...  virginica
# 144                6.7  ...  virginica
# 145                6.7  ...  virginica
# 146                6.3  ...  virginica
# 147                6.5  ...  virginica
# 148                6.2  ...  virginica
# 149                5.9  ...  virginica
#
# [36 rows x 5 columns]
# Rank:  1 , recvbuf:      sepal length (cm)  ...     species
# 38                4.4  ...      setosa
# 39                5.1  ...      setosa
# 40                5.0  ...      setosa
# 41                4.5  ...      setosa
# 42                4.4  ...      setosa
# 43                5.0  ...      setosa
# 44                5.1  ...      setosa
# 45                4.8  ...      setosa
# 46                5.1  ...      setosa
# 47                4.6  ...      setosa
# 48                5.3  ...      setosa
# 49                5.0  ...      setosa
# 50                7.0  ...  versicolor
# 51                6.4  ...  versicolor
# 52                6.9  ...  versicolor
# 53                5.5  ...  versicolor
# 54                6.5  ...  versicolor
# 55                5.7  ...  versicolor
# 56                6.3  ...  versicolor
# 57                4.9  ...  versicolor
# 58                6.6  ...  versicolor
# 59                5.2  ...  versicolor
# 60                5.0  ...  versicolor
# 61                5.9  ...  versicolor
# 62                6.0  ...  versicolor
# 63                6.1  ...  versicolor
# 64                5.6  ...  versicolor
# 65                6.7  ...  versicolor
# 66                5.6  ...  versicolor
# 67                5.8  ...  versicolor
# 68                6.2  ...  versicolor
# 69                5.6  ...  versicolor
# 70                5.9  ...  versicolor
# 71                6.1  ...  versicolor
# 72                6.3  ...  versicolor
# 73                6.1  ...  versicolor
# 74                6.4  ...  versicolor
# 75                6.6  ...  versicolor
#
# [38 rows x 5 columns]

# %% [markdown]
# #### **Gather Operation on the Dataframe**

# %%
# %%writefile GatherringDataframe.py
from mpi4py import MPI # Importing mpi4py package from MPI module
import numpy as np
import pandas as pd
from decimal import Decimal, ROUND_HALF_UP # Importing Decimal, ROUND_HALF_UP functions from the decimal package

FILENAME = "/content/iris_dataset.csv" # Storing File path
# Defining a function to load the data
def loadData(filename): 
    # Loading the dataset with column names as 
    data = pd.read_csv(filename)
    # Returning the dataframe
    return data
# Calling the function loadData and storing the dataframe in a variable named df
df = loadData(FILENAME)

# Defining a function 
def main():
    # communicator
    comm = MPI.COMM_WORLD
    rank = comm.Get_rank()   # number of the process running the code
    size = comm.Get_size()   # total number of processes running
    slice_for_each_worker = int(Decimal(df.shape[0]/size).quantize(Decimal('1.'), rounding = ROUND_HALF_UP))   # Number of elements in a array for each rank 
    # Creating a sender buffer array 
    if rank < size-1:
        sendbuf = df[slice_for_each_worker*rank:slice_for_each_worker*(rank+1)]
    else:
        sendbuf = df[slice_for_each_worker*rank:]
    # Printing the result
    print('Rank: ',rank, ', sendbuf: ', sendbuf)
    recvbuf = None
    # Gathering the Information
    recvbuf = comm.gather(sendbuf, root = 0)
    # Display the result
    if rank == 0:
        print('Rank: ',rank, ', recvbuf received: ', recvbuf)

# Calling a function
main()
# Out:
# Writing GatherringDataframe.py

# %%
! mpirun --allow-run-as-root -np 4 python GatherringDataframe.py
# Out:
# Rank:  2 , sendbuf:       sepal length (cm)  ...     species
# 76                 6.8  ...  versicolor
# 77                 6.7  ...  versicolor
# 78                 6.0  ...  versicolor
# 79                 5.7  ...  versicolor
# 80                 5.5  ...  versicolor
# 81                 5.5  ...  versicolor
# 82                 5.8  ...  versicolor
# 83                 6.0  ...  versicolor
# 84                 5.4  ...  versicolor
# 85                 6.0  ...  versicolor
# 86                 6.7  ...  versicolor
# 87                 6.3  ...  versicolor
# 88                 5.6  ...  versicolor
# 89                 5.5  ...  versicolor
# 90                 5.5  ...  versicolor
# 91                 6.1  ...  versicolor
# 92                 5.8  ...  versicolor
# 93                 5.0  ...  versicolor
# 94                 5.6  ...  versicolor
# 95                 5.7  ...  versicolor
# 96                 5.7  ...  versicolor
# 97                 6.2  ...  versicolor
# 98                 5.1  ...  versicolor
# 99                 5.7  ...  versicolor
# 100                6.3  ...   virginica
# 101                5.8  ...   virginica
# 102                7.1  ...   virginica
# 103                6.3  ...   virginica
# 104                6.5  ...   virginica
# 105                7.6  ...   virginica
# 106                4.9  ...   virginica
# 107                7.3  ...   virginica
# 108                6.7  ...   virginica
# 109                7.2  ...   virginica
# 110                6.5  ...   virginica
# 111                6.4  ...   virginica
# 112                6.8  ...   virginica
# 113                5.7  ...   virginica
#
# [38 rows x 5 columns]
# Rank:  3 , sendbuf:       sepal length (cm)  ...    species
# 114                5.8  ...  virginica
# 115                6.4  ...  virginica
# 116                6.5  ...  virginica
# 117                7.7  ...  virginica
# 118                7.7  ...  virginica
# 119                6.0  ...  virginica
# 120                6.9  ...  virginica
# 121                5.6  ...  virginica
# 122                7.7  ...  virginica
# 123                6.3  ...  virginica
# 124                6.7  ...  virginica
# 125                7.2  ...  virginica
# 126                6.2  ...  virginica
# 127                6.1  ...  virginica
# 128                6.4  ...  virginica
# 129                7.2  ...  virginica
# 130                7.4  ...  virginica
# 131                7.9  ...  virginica
# 132                6.4  ...  virginica
# 133                6.3  ...  virginica
# 134                6.1  ...  virginica
# 135                7.7  ...  virginica
# 136                6.3  ...  virginica
# 137                6.4  ...  virginica
# 138                6.0  ...  virginica
# 139                6.9  ...  virginica
# 140                6.7  ...  virginica
# 141                6.9  ...  virginica
# 142                5.8  ...  virginica
# 143                6.8  ...  virginica
# 144                6.7  ...  virginica
# 145                6.7  ...  virginica
# 146                6.3  ...  virginica
# 147                6.5  ...  virginica
# 148                6.2  ...  virginica
# 149                5.9  ...  virginica
#
# [36 rows x 5 columns]
# Rank:  0 , sendbuf:      sepal length (cm)  ...  species
# 0                 5.1  ...   setosa
# 1                 4.9  ...   setosa
# 2                 4.7  ...   setosa
# 3                 4.6  ...   setosa
# 4                 5.0  ...   setosa
# 5                 5.4  ...   setosa
# 6                 4.6  ...   setosa
# 7                 5.0  ...   setosa
# 8                 4.4  ...   setosa
# 9                 4.9  ...   setosa
# 10                5.4  ...   setosa
# 11                4.8  ...   setosa
# 12                4.8  ...   setosa
# 13                4.3  ...   setosa
# 14                5.8  ...   setosa
# 15                5.7  ...   setosa
# 16                5.4  ...   setosa
# 17                5.1  ...   setosa
# 18                5.7  ...   setosa
# 19                5.1  ...   setosa
# 20                5.4  ...   setosa
# 21                5.1  ...   setosa
# 22                4.6  ...   setosa
# 23                5.1  ...   setosa
# 24                4.8  ...   setosa
# 25                5.0  ...   setosa
# 26                5.0  ...   setosa
# 27                5.2  ...   setosa
# 28                5.2  ...   setosa
# 29                4.7  ...   setosa
# 30                4.8  ...   setosa
# 31                5.4  ...   setosa
# 32                5.2  ...   setosa
# 33                5.5  ...   setosa
# 34                4.9  ...   setosa
# 35                5.0  ...   setosa
# 36                5.5  ...   setosa
# 37                4.9  ...   setosa
#
# [38 rows x 5 columns]
# Rank:  1 , sendbuf:      sepal length (cm)  ...     species
# 38                4.4  ...      setosa
# 39                5.1  ...      setosa
# 40                5.0  ...      setosa
# 41                4.5  ...      setosa
# 42                4.4  ...      setosa
# 43                5.0  ...      setosa
# 44                5.1  ...      setosa
# 45                4.8  ...      setosa
# 46                5.1  ...      setosa
# 47                4.6  ...      setosa
# 48                5.3  ...      setosa
# 49                5.0  ...      setosa
# 50                7.0  ...  versicolor
# 51                6.4  ...  versicolor
# 52                6.9  ...  versicolor
# 53                5.5  ...  versicolor
# 54                6.5  ...  versicolor
# 55                5.7  ...  versicolor
# 56                6.3  ...  versicolor
# 57                4.9  ...  versicolor
# 58                6.6  ...  versicolor
# 59                5.2  ...  versicolor
# 60                5.0  ...  versicolor
# 61                5.9  ...  versicolor
# 62                6.0  ...  versicolor
# 63                6.1  ...  versicolor
# 64                5.6  ...  versicolor
# 65                6.7  ...  versicolor
# 66                5.6  ...  versicolor
# 67                5.8  ...  versicolor
# 68                6.2  ...  versicolor
# 69                5.6  ...  versicolor
# 70                5.9  ...  versicolor
# 71                6.1  ...  versicolor
# 72                6.3  ...  versicolor
# 73                6.1  ...  versicolor
# 74                6.4  ...  versicolor
# 75                6.6  ...  versicolor
#
# [38 rows x 5 columns]
# Rank:  0 , recvbuf received:  [    sepal length (cm)  ...  species
# 0                 5.1  ...   setosa
# 1                 4.9  ...   setosa
# 2                 4.7  ...   setosa
# 3                 4.6  ...   setosa
# 4                 5.0  ...   setosa
# 5                 5.4  ...   setosa
# 6                 4.6  ...   setosa
# 7                 5.0  ...   setosa
# 8                 4.4  ...   setosa
# 9                 4.9  ...   setosa
# 10                5.4  ...   setosa
# 11                4.8  ...   setosa
# 12                4.8  ...   setosa
# 13                4.3  ...   setosa
# 14                5.8  ...   setosa
# 15                5.7  ...   setosa
# 16                5.4  ...   setosa
# 17                5.1  ...   setosa
# 18                5.7  ...   setosa
# 19                5.1  ...   setosa
# 20                5.4  ...   setosa
# 21                5.1  ...   setosa
# 22                4.6  ...   setosa
# 23                5.1  ...   setosa
# 24                4.8  ...   setosa
# 25                5.0  ...   setosa
# 26                5.0  ...   setosa
# 27                5.2  ...   setosa
# 28                5.2  ...   setosa
# 29                4.7  ...   setosa
# 30                4.8  ...   setosa
# 31                5.4  ...   setosa
# 32                5.2  ...   setosa
# 33                5.5  ...   setosa
# 34                4.9  ...   setosa
# 35                5.0  ...   setosa
# 36                5.5  ...   setosa
# 37                4.9  ...   setosa
#
# [38 rows x 5 columns],     sepal length (cm)  ...     species
# 38                4.4  ...      setosa
# 39                5.1  ...      setosa
# 40                5.0  ...      setosa
# 41                4.5  ...      setosa
# 42                4.4  ...      setosa
# 43                5.0  ...      setosa
# 44                5.1  ...      setosa
# 45                4.8  ...      setosa
# 46                5.1  ...      setosa
# 47                4.6  ...      setosa
# 48                5.3  ...      setosa
# 49                5.0  ...      setosa
# 50                7.0  ...  versicolor
# 51                6.4  ...  versicolor
# 52                6.9  ...  versicolor
# 53                5.5  ...  versicolor
# 54                6.5  ...  versicolor
# 55                5.7  ...  versicolor
# 56                6.3  ...  versicolor
# 57                4.9  ...  versicolor
# 58                6.6  ...  versicolor
# 59                5.2  ...  versicolor
# 60                5.0  ...  versicolor
# 61                5.9  ...  versicolor
# 62                6.0  ...  versicolor
# 63                6.1  ...  versicolor
# 64                5.6  ...  versicolor
# 65                6.7  ...  versicolor
# 66                5.6  ...  versicolor
# 67                5.8  ...  versicolor
# 68                6.2  ...  versicolor
# 69                5.6  ...  versicolor
# 70                5.9  ...  versicolor
# 71                6.1  ...  versicolor
# 72                6.3  ...  versicolor
# 73                6.1  ...  versicolor
# 74                6.4  ...  versicolor
# 75                6.6  ...  versicolor
#
# [38 rows x 5 columns],      sepal length (cm)  ...     species
# 76                 6.8  ...  versicolor
# 77                 6.7  ...  versicolor
# 78                 6.0  ...  versicolor
# 79                 5.7  ...  versicolor
# 80                 5.5  ...  versicolor
# 81                 5.5  ...  versicolor
# 82                 5.8  ...  versicolor
# 83                 6.0  ...  versicolor
# 84                 5.4  ...  versicolor
# 85                 6.0  ...  versicolor
# 86                 6.7  ...  versicolor
# 87                 6.3  ...  versicolor
# 88                 5.6  ...  versicolor
# 89                 5.5  ...  versicolor
# 90                 5.5  ...  versicolor
# 91                 6.1  ...  versicolor
# 92                 5.8  ...  versicolor
# 93                 5.0  ...  versicolor
# 94                 5.6  ...  versicolor
# 95                 5.7  ...  versicolor
# 96                 5.7  ...  versicolor
# 97                 6.2  ...  versicolor
# 98                 5.1  ...  versicolor
# 99                 5.7  ...  versicolor
# 100                6.3  ...   virginica
# 101                5.8  ...   virginica
# 102                7.1  ...   virginica
# 103                6.3  ...   virginica
# 104                6.5  ...   virginica
# 105                7.6  ...   virginica
# 106                4.9  ...   virginica
# 107                7.3  ...   virginica
# 108                6.7  ...   virginica
# 109                7.2  ...   virginica
# 110                6.5  ...   virginica
# 111                6.4  ...   virginica
# 112                6.8  ...   virginica
# 113                5.7  ...   virginica
#
# [38 rows x 5 columns],      sepal length (cm)  ...    species
# 114                5.8  ...  virginica
# 115                6.4  ...  virginica
# 116                6.5  ...  virginica
# 117                7.7  ...  virginica
# 118                7.7  ...  virginica
# 119                6.0  ...  virginica
# 120                6.9  ...  virginica
# 121                5.6  ...  virginica
# 122                7.7  ...  virginica
# 123                6.3  ...  virginica
# 124                6.7  ...  virginica
# 125                7.2  ...  virginica
# 126                6.2  ...  virginica
# 127                6.1  ...  virginica
# 128                6.4  ...  virginica
# 129                7.2  ...  virginica
# 130                7.4  ...  virginica
# 131                7.9  ...  virginica
# 132                6.4  ...  virginica
# 133                6.3  ...  virginica
# 134                6.1  ...  virginica
# 135                7.7  ...  virginica
# 136                6.3  ...  virginica
# 137                6.4  ...  virginica
# 138                6.0  ...  virginica
# 139                6.9  ...  virginica
# 140                6.7  ...  virginica
# 141                6.9  ...  virginica
# 142                5.8  ...  virginica
# 143                6.8  ...  virginica
# 144                6.7  ...  virginica
# 145                6.7  ...  virginica
# 146                6.3  ...  virginica
# 147                6.5  ...  virginica
# 148                6.2  ...  virginica
# 149                5.9  ...  virginica
#
# [36 rows x 5 columns]]
