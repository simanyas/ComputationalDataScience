# %% [markdown]
# ### Revision Notebook (ungraded)
# Classify Fashion-MNIST with a simple CNN in Keras

# %% [markdown]
# Clothing classification from images has practical applications
# in e-commerce and online advertising. Some of its use cases are:
#   - Identifying similar clothing from a large set of images, given a
# clothing image
#   - Prediction of compatible outfit and shoes
#   - Automatic inventory assessment in clothing stores
#   - Automatic segmentation of clothing for fashion trend prediction

# %%
import tensorflow as tf

import numpy as np
import matplotlib.pyplot as plt

# Load the fashion-mnist pre-shuffled train data and test data
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.fashion_mnist.load_data()

print("x_train shape:", x_train.shape, "y_train shape:", y_train.shape)
# Out:
# ...
# 4431872/4422102 [==============================] - 0s 0us/step
# x_train shape: (60000, 28, 28) y_train shape: (60000,)

# %% [markdown]
# ## Visualize the data

# %%
# Print training set shape - note there are 60,000 training data of image size of 28x28, 60,000 train labels)
print("x_train shape:", x_train.shape, "y_train shape:", y_train.shape)

# Print the number of training and test datasets
print(x_train.shape[0], 'train set')
print(x_test.shape[0], 'test set')

# Define the text labels
fashion_mnist_labels = ["T-shirt/top",  # index 0
                        "Trouser",      # index 1
                        "Pullover",     # index 2 
                        "Dress",        # index 3 
                        "Coat",         # index 4
                        "Sandal",       # index 5
                        "Shirt",        # index 6 
                        "Sneaker",      # index 7 
                        "Bag",          # index 8 
                        "Ankle boot"]   # index 9

# Image index, you can pick any number between 0 and 59,999
img_index = 5
# y_train contains the labels, ranging from 0 to 9
label_index = y_train[img_index]
# Print the label, for example 2 - Pullover
print ("y = " + str(label_index) + " " +(fashion_mnist_labels[label_index]))
# # Show one of the images from the training dataset
plt.imshow(x_train[img_index])
# Out:
# x_train shape: (60000, 28, 28) y_train shape: (60000,)
# 60000 train set
# 10000 test set
# y = 2 Pullover

# %%
w, h = 28, 28
x_train = x_train.reshape(x_train.shape[0], w, h, 1)
x_test = x_test.reshape(x_test.shape[0], w, h, 1)

x_train.shape
# Out:
# (60000, 28, 28, 1)

# %%
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Dropout, Flatten

model = tf.keras.Sequential()

model.add(Conv2D(filters=64, kernel_size=2, padding='same', activation='relu', input_shape=(28,28,1))) 
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.3))

model.add(Conv2D(filters=32, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.3))

model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 28, 28, 64)        320
#
#  max_pooling2d (MaxPooling2D  (None, 14, 14, 64)       0
#  )
#
#  dropout (Dropout)           (None, 14, 14, 64)        0
#
#  conv2d_1 (Conv2D)           (None, 14, 14, 32)        8224
#
#  max_pooling2d_1 (MaxPooling  (None, 7, 7, 32)         0
#  2D)
#
#  dropout_1 (Dropout)         (None, 7, 7, 32)          0
#
#  flatten (Flatten)           (None, 1568)              0
#
#  dense (Dense)               (None, 256)               401664
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 10)                2570
#
# ...
# Total params: 412,778
# Trainable params: 412,778
# Non-trainable params: 0
# _________________________________________________________________

# %%
BATCH_SIZE=1000
EPOCHS = 20

model.compile(loss='sparse_categorical_crossentropy',
             optimizer='adam',
             metrics=['accuracy'])
# %time history = model.fit(x_train, y_train, epochs=EPOCHS, batch_size=BATCH_SIZE, validation_split=0.2, verbose=1)
# Out:
# Epoch 1/20
# 48/48 [==============================] - 15s 37ms/step - loss: 6.1072 - accuracy: 0.4286 - val_loss: 0.8339 - val_accuracy: 0.6768
# Epoch 2/20
# 48/48 [==============================] - 2s 34ms/step - loss: 1.0434 - accuracy: 0.6294 - val_loss: 0.6303 - val_accuracy: 0.7586
# Epoch 3/20
# 48/48 [==============================] - 2s 34ms/step - loss: 0.8398 - accuracy: 0.6947 - val_loss: 0.5552 - val_accuracy: 0.7851
# Epoch 4/20
# 48/48 [==============================] - 2s 34ms/step - loss: 0.7536 - accuracy: 0.7240 - val_loss: 0.5221 - val_accuracy: 0.7960
# Epoch 5/20
# 48/48 [==============================] - 2s 34ms/step - loss: 0.6977 - accuracy: 0.7386 - val_loss: 0.4992 - val_accuracy: 0.8112
# Epoch 6/20
# 48/48 [==============================] - 2s 33ms/step - loss: 0.6487 - accuracy: 0.7572 - val_loss: 0.4707 - val_accuracy: 0.8196
# Epoch 7/20
# ...

# %%
train_loss, train_accuracy = model.evaluate(x_train, y_train, batch_size=BATCH_SIZE)
train_accuracy
# Out:
# 60/60 [==============================] - 1s 12ms/step - loss: 0.3250 - accuracy: 0.8773
# 0.8772666454315186

# %%
test_loss, test_accuracy = model.evaluate(x_test, y_test, batch_size=BATCH_SIZE)
test_accuracy
# Out:
# 10/10 [==============================] - 0s 15ms/step - loss: 0.3624 - accuracy: 0.8664
# 0.8664000034332275

# %%
import pandas as pd

def plot_history(history, samples=10, init_phase_samples=None):
    epochs = history.params['epochs']
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']

    every_sample =  int(epochs / samples)
    acc = pd.DataFrame(acc).iloc[::every_sample, :]
    val_acc = pd.DataFrame(val_acc).iloc[::every_sample, :]

    fig, ax = plt.subplots(figsize=(20,5))

    ax.plot(acc, 'bo', label='Training acc')
    ax.plot(val_acc, 'b', label='Validation acc')
    ax.set_title('Training and validation accuracy')
    ax.legend()

plot_history(history)

# %%
y_hat = model.predict(x_test)

# Plot a random sample of 10 test images, their predicted labels and ground truth
figure = plt.figure(figsize=(20, 8))
for i, index in enumerate(np.random.choice(x_test.shape[0], size=15, replace=False)):
    ax = figure.add_subplot(3, 5, i + 1, xticks=[], yticks=[])
    # Display each image
    ax.imshow(np.squeeze(x_test[index]))
    predict_index = np.argmax(y_hat[index])
    true_index = y_test[index]
    # Set the title for each image
    ax.set_title("{} ({})".format(fashion_mnist_labels[predict_index], 
                                  fashion_mnist_labels[true_index]),
                                  color=("green" if predict_index == true_index else "red"))
